# %% [markdown]
# # Trial Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/programming languages 2004-2024.csv')

# %%
data.head()
# Out:
#         Month                Attribute  Value
# 0  01/01/2004      Python Worldwide(%)     30
# 1  01/01/2004  JavaScript Worldwide(%)     98
# 2  01/01/2004        Java Worldwide(%)     96
# 3  01/01/2004          C# Worldwide(%)     76
# 4  01/01/2004         PhP Worldwide(%)    100

# %%
data.shape
# Out:
# (2490, 3)

# %%
data.isnull().sum()
# Out:
# Month        0
# Attribute    0
# Value        0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# False

# %%
data.describe()
# Out:
#              Value
# count  2490.000000
# mean     38.064257
# std      26.285081
# min       1.000000
# 25%      18.000000
# 50%      35.000000
# 75%      55.000000
# max     100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2490 entries, 0 to 2489
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      2490 non-null   object
#  1   Attribute  2490 non-null   object
#  2   Value      2490 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 58.5+ KB

# %%
data.head(2)
# Out:
#         Month                Attribute  Value
# 0  01/01/2004      Python Worldwide(%)     30
# 1  01/01/2004  JavaScript Worldwide(%)     98

# %%
data['Attribute'] = data['Attribute'].str.replace('(%)', '')

# %%
data['Attribute'].value_counts()
# Out:
# Attribute
# Python Worldwide        249
# JavaScript Worldwide    249
# Java Worldwide          249
# C# Worldwide            249
# PhP Worldwide           249
# Flutter Worldwide       249
# React Worldwide         249
# Swift Worldwide         249
# TypeScript Worldwide    249
# Matlab Worldwide        249
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=40)
sns.countplot(data, x='Attribute')
# Out:
# <Axes: xlabel='Attribute', ylabel='count'>
